# %%
# !ARCHFLAGS="-arch x86_64" pip install allennlp

# %%
# %load_ext autoreload
# %autoreload 2
from visualization.pretrained_model_loader import QAModel, ModelType
from visualization.visualizer import Visualizer
from allennlp.modules.elmo import Elmo
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Define Elmo model 
model = Elmo(options_file="../models/elmo_allennlp/elmo_options_small.json", weight_file="../models/elmo_allennlp/elmo_weights_small.hdf5", num_output_representations=2)
# Out:
# 2021-06-22 00:46:06,172 Initializing ELMo
